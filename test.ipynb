# %%
import turtle

amy = turtle.Turtle()
amy.color('red')
amy.forward(100)
amy.right(90)
amy.color('orange')
amy.forward(100)
amy.right(90)
amy.color('yellow') 
amy.forward(100)
amy.right(90)
amy.color('green')
amy.forward(100)
amy.right(90)

# %%
amy.color('red')

for side in range(4):
    amy.forward(100)
    amy.right(90)
    for k in range(4):
        amy.forward(10)
        amy.right(90)
